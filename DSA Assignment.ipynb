# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  Read the dataset to python environment

# %%
Iris= pd.read_excel(r'C:\Users\reshm\Downloads\iris.xls')

# %%
Iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # Display the columns in the dataset

# %%
Iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculate the mean of each column of the dataset.

# %%
Iris.mean()
# Out:
# C:\Users\reshm\AppData\Local\Temp\ipykernel_30084\4049886577.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## Check for the null values present in the dataset.

# %%
Iris.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# # visualizations using the dataset

# %% [markdown]
# # Scatterplot Of relationship with Dimension of each classification

# %% [markdown]
# ##Comparing Sepal Length and Sepal Width

# %%
sns.scatterplot(x='SL', y='SW',
                hue='Classification', data=Iris, )
 
# Placing Legend
plt.legend()
 
plt.show()

# %% [markdown]
# ##Comparing Petal Length and Petal Width

# %%
sns.scatterplot(x='PL', y='PW',
                hue='Classification', data=Iris, )
 
# Placing Legend
plt.legend()
 
plt.show()

# %% [markdown]
# # BAR Chart Comparison of Each Flower Dimension with Classification

# %% [markdown]
# ## Sepal Length

# %%
plt.bar(data['Classification'],data['SL'])
plt.xticks(rotation=90)
plt.xlabel('Classification')
plt.ylabel('Sepal Length')
plt.show()

# %% [markdown]
# ## Sepal Width

# %%
plt.bar(data['Classification'],data['SW'])
plt.xticks(rotation=90)
plt.xlabel('Classification')
plt.ylabel('Sepal Width')
plt.show()

# %% [markdown]
# ## Petal length

# %%
plt.bar(data['Classification'],data['PL'])
plt.xticks(rotation=90)
plt.xlabel('Classification')
plt.ylabel('Petal Length')
plt.show()

# %% [markdown]
# ## Petal Width

# %%
plt.bar(data['Classification'],data['PW'])
plt.xticks(rotation=90)
plt.xlabel('Classification')
plt.ylabel('Petal Width')
plt.show()

# %% [markdown]
# ## Co-Relation with each Dimension

# %%
corr_matrix=Iris.corr()
sns.heatmap(corr_matrix,annot=True, cmap='PiYG')
# Out:
# C:\Users\reshm\AppData\Local\Temp\ipykernel_30084\4273420850.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=Iris.corr()
# <Axes: >
